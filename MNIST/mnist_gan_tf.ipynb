# %%
# https://github.com/znxlwm/tensorflow-MNIST-GAN-DCGAN
# https://github.com/znxlwm/tensorflow-MNIST-GAN-DCGAN/blob/master/tensorflow_MNIST_GAN.py

import os, time, itertools, pickle, imageio
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

random_dim = 100

def generator(x):
    # initializers
    w_init = tf.truncated_normal_initializer(mean=0, stddev=0.02)
    b_init = tf.constant_initializer(0.)
    
    # 1st hidden layer
    w0 = tf.get_variable('G_w0', [x.get_shape()[1], 256], initializer=w_init)
    b0 = tf.get_variable('G_b0', [256], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)
    
    # 2nd hidden layer
    w1 = tf.get_variable('G_w1', [h0.get_shape()[1], 512], initializer=w_init)
    b1 = tf.get_variable('G_b1', [512], initializer=b_init)
    h1 = tf.nn.relu(tf.matmul(h0, w1) + b1)
    
    # 3rd hidden layer
    w2 = tf.get_variable('G_w2', [h1.get_shape()[1], 1024], initializer=w_init)
    b2 = tf.get_variable('G_b2', [1024], initializer=b_init)
    h2 = tf.nn.relu(tf.matmul(h1, w2) + b2)
    
    # output hidden layer
    w3 = tf.get_variable('G_w3', [h2.get_shape()[1], 784], initializer=w_init)
    b3 = tf.get_variable('G_b3', [784], initializer=b_init)
    output = tf.nn.relu(tf.matmul(h2, w3) + b3)
    
    return output


def discriminator(x, drop_out):
    # initializers
    w_init = tf.truncated_normal_initializer(mean=0, stddev=0.02)
    b_init = tf.constant_initializer(0.)
    
    # 1st hidden layer
    w0 = tf.get_variable('D_w0', [x.get_shape()[1], 1024], initializer=w_init)
    b0 = tf.get_variable('D_b0', [1024], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)
    h0 = tf.nn.dropout(h0, drop_out)
    
    # 2nd hidden layer
    w1 = tf.get_variable('D_w1', [h0.get_shape()[1], 512], initializer=w_init)
    b1 = tf.get_variable('D_b1', [512], initializer=b_init)
    h1 = tf.nn.relu(tf.matmul(h0, w1) + b1)
    h1 = tf.nn.dropout(h1, drop_out)
    
    # 3rd hidden layer
    w2 = tf.get_variable('D_w2', [h1.get_shape()[1], 256], initializer=w_init)
    b2 = tf.get_variable('D_b2', [256], initializer=b_init)
    h2 = tf.nn.relu(tf.matmul(h1, w2) + b2)
    h2 = tf.nn.dropout(h2, drop_out)
    
    # output layer
    w3 = tf.get_variable('D_w3', [h2.get_shape()[1], 1], initializer=w_init)
    b3 = tf.get_variable('D_b3', [1], initializer=b_init)
    output = tf.nn.sigmoid(tf.matmul(h2, w3) + b3)
    
    return output


fixed_z_ = np.random.normal(0, 1, (25, 100)) 
def show_result(num_epoch, show=False, save=False, path='result.png', isFix=False):
    z_ = np.random.normal(0, 1, (25, 100))

    if isFix:
        test_images = sess.run(G_z, {z: fixed_z_, drop_out: 0.0})
    else:
        test_images = sess.run(G_z, {z: z_, drop_out: 0.0})

    size_figure_grid = 5
    fig, ax = plt.subplots(size_figure_grid, size_figure_grid, figsize=(5, 5))
    for i, j in itertools.product(range(size_figure_grid), range(size_figure_grid)):
        ax[i, j].get_xaxis().set_visible(False)
        ax[i, j].get_yaxis().set_visible(False)

    for k in range(5*5):
        i = k // 5
        j = k % 5
        ax[i, j].cla()
        ax[i, j].imshow(np.reshape(test_images[k], (28, 28)), cmap='gray')

    label = 'Epoch {0}'.format(num_epoch)
    fig.text(0.5, 0.04, label, ha='center')
    plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()
    

def show_train_hist(hist, show=False, save=False, path='train_hist.png'):
    x = range(len(hist['D_losses']))
    
    y1 = hist['D_losses']
    y2 = hist['G_losses']
    
    plt.plot(x, y1, labels='D_loss')
    plt.plot(x, y2, labels='G_loss')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    
    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()
    
    if save:
        plt.savefig(path)
        
    if show:
        plt.show()
    else:
        plt.close()


batch_size = 100
learning_rate = 0.0002
epochs = 100

mnist = input_data.read_data_sets('mnist_data/', one_hot=True)
train_set = (mnist.train.images - 0.5) / 0.5  # normalization: range: -1 ~ 1


# networks: generator
with tf.variable_scope('G'):
    z = tf.placeholder(tf.float32, shape=(None, 100))
    G_z = generator(z)
    
    
# networks: discriminator
with tf.variable_scope('D') as scope:
    drop_out = tf.placeholder(tf.float32, name='drop_out')
    x = tf.placeholder(tf.float32, shape=(None, 784))
    D_real = discriminator(x, drop_out)
    scope.reuse_variables()
    D_fake = discriminator(G_z, drop_out)
    

# loss for each network
eps = 1e-2
D_loss = tf.reduce_mean(-tf.log(D_real + eps) - tf.log(1 - D_fake + eps))
G_loss = tf.reduce_mean(-tf.log(D_fake + eps))

# trainable variables for each network
t_vars = tf.trainable_variables()
D_vars = [var for var in t_vars if 'D_' in var.name]
G_vars = [var for var in t_vars if 'G_' in var.name]

# optimizer for each network
D_optim = tf.train.AdamOptimizer(learning_rate).minimize(D_loss, var_list=D_vars)
G_optim = tf.train.AdamOptimizer(learning_rate).minimize(G_loss, var_list=G_vars)

# open session and initialize all variables
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()

# results save folder
if not os.path.isdir('MNIST_GAN_results'):
    os.mkdir('MNIST_GAN_results')
if not os.path.isdir('MNIST_GAN_results/Random_results'):
    os.mkdir('MNIST_GAN_results/Random_results')
if not os.path.isdir('MNIST_GAN_results/Fixed_results'):
    os.mkdir('MNIST_GAN_results/Fixed_results')
    
train_hist = {}
train_hist['D_losses'] = []
train_hist['G_losses'] = []
train_hist['per_epoch_ptimes'] = []
train_hist['total_ptime'] = []

# training loop
np.random.seed(int(time.time()))
start_time = time.time()
for epoch in range(epochs):
    G_losses = []
    D_losses = []
    epoch_start_time = time.time()
    
    batches = train_set.shape[0] // batch_size
    for batch_i in range(batches):
        
        # update discriminator
        x_ = train_set[batch_i*batch_size:(batch_i+1)*batch_size]
        z_ = np.random.normal(0, 1, (batch_size, 100))
        
        d_loss_, _ = sess.run([D_loss, D_optim], feed_dict={x:x_, z:z_, drop_out:0.3})
        D_losses.append(d_loss_)
        
        # update generator
        z_ = np.random.normal(0, 1, (batch_size, 100))
        g_loss_, _ = sess.run([G_loss, G_optim], feed_dict={z: z_, drop_out:0.3})
        G_losses.append(g_loss_)
        
    epoch_end_time = time.time()
    per_epoch_ptimes = epoch_end_time - epoch_start_time
    print("Epoch: {}/{}, {:.2f}s/epoch, d_loss mean: {:.5f}, g_loss mean: {:.5f}"
          .format(epoch, epochs, per_epoch_ptimes, np.mean(D_losses), np.mean(G_losses)))
    
    p = 'MNIST_GAN_results/Random_results/MNIST_GAN_' + str(epoch + 1) + '.png'
    fixed_p = 'MNIST_GAN_results/Fixed_results/MNIST_GAN_' + str(epoch + 1) + '.png'
    show_result((epoch + 1), save=True, path=p, isFix=False)
    show_result((epoch + 1), save=True, path=fixed_p, isFix=True)

    train_hist['D_losses'].append(np.mean(D_losses))
    train_hist['G_losses'].append(np.mean(G_losses))
    train_hist['per_epoch_ptimes'].append(per_epoch_ptimes)
    
end_time = time.time()
total_ptime = end_time - start_time
train_hist['total_ptime'].append(total_ptime)
        
print("Avg per epoch ptime: {}, {} Epochs have taken {:.2f}"
      .format(np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
print('Training Finished!')
with open('MNIST_GAN_results/train_hist.pkl', 'wb') as f:
    pickle.dump(train_hist, f)
    
show_train_hist(train_hist, save=True, path='MNIST_GAN_results/MNIST_GAN_train_hist.png')

images = []
for e in range(epochs):
    img_name = 'MNIST_GAN_results/Fixed_results/MNIST_GAN_' + str(e + 1) + '.png'
    images.append(imageio.imread(img_name))
imageio.mimsave('MNIST_GAN_results/generation_animation.gif', images, fps=5)
    
sess.close()
# Out:
# WARNING:tensorflow:From <ipython-input-1-550860f133ba>:132: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting mnist_data/t10k-images-idx3-ubyte.gz
# Extracting mnist_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: __init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Epoch: 0/100, 39.82s/epoch, d_loss mean: 0.13409, g_loss mean: 3.52147
# Epoch: 1/100, 40.71s/epoch, d_loss mean: -0.01972, g_loss mean: 4.58912
# Epoch: 2/100, 38.31s/epoch, d_loss mean: -0.01985, g_loss mean: 4.60015
# Epoch: 3/100, 38.49s/epoch, d_loss mean: -0.01987, g_loss mean: 4.60255
# Epoch: 4/100, 38.22s/epoch, d_loss mean: -0.01988, g_loss mean: 4.60356
# Epoch: 5/100, 37.45s/epoch, d_loss mean: -0.01989, g_loss mean: 4.60410
# Epoch: 6/100, 40.75s/epoch, d_loss mean: -0.01989, g_loss mean: 4.60449
# Epoch: 7/100, 39.49s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60469
# Epoch: 8/100, 38.31s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60484
# Epoch: 9/100, 40.37s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60495
# Epoch: 10/100, 41.09s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60500
# Epoch: 11/100, 42.63s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60504
# Epoch: 12/100, 41.83s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60509
# Epoch: 13/100, 38.66s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60511
# Epoch: 14/100, 38.25s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60513
# Epoch: 15/100, 41.35s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60514
# Epoch: 16/100, 36.55s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60514
# Epoch: 17/100, 36.96s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60515
# Epoch: 18/100, 40.07s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60515
# Epoch: 19/100, 42.33s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60515
# Epoch: 20/100, 41.00s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60516
# Epoch: 21/100, 39.05s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60516
# Epoch: 22/100, 41.18s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 23/100, 40.17s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 24/100, 41.96s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 25/100, 46.02s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 26/100, 44.25s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 27/100, 38.97s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 28/100, 40.66s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 29/100, 42.71s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 30/100, 40.73s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 31/100, 39.50s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 32/100, 40.96s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 33/100, 41.49s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 34/100, 43.51s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 35/100, 39.30s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 36/100, 39.93s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 37/100, 41.51s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 38/100, 48.28s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 39/100, 45.86s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 40/100, 45.13s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 41/100, 46.11s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 42/100, 48.42s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 43/100, 50.42s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 44/100, 47.84s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 45/100, 46.98s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 46/100, 44.76s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 47/100, 47.48s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 48/100, 47.04s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 49/100, 49.87s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 50/100, 50.52s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 51/100, 42.57s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 52/100, 40.26s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 53/100, 39.40s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 54/100, 41.46s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 55/100, 38.68s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 56/100, 40.66s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 57/100, 40.56s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 58/100, 38.60s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 59/100, 39.10s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 60/100, 38.15s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 61/100, 39.55s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 62/100, 40.42s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 63/100, 37.55s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 64/100, 37.45s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 65/100, 38.01s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 66/100, 36.79s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 67/100, 40.33s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 68/100, 37.30s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 69/100, 37.48s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 70/100, 37.60s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 71/100, 37.53s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 72/100, 36.81s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 73/100, 36.93s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 74/100, 37.75s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 75/100, 37.47s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 76/100, 39.40s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 77/100, 39.60s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 78/100, 36.58s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 79/100, 37.13s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 80/100, 36.66s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 81/100, 38.42s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 82/100, 36.49s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 83/100, 37.22s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 84/100, 36.56s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 85/100, 47.17s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 86/100, 45.04s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 87/100, 44.59s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 88/100, 49.46s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 89/100, 44.97s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 90/100, 42.29s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 91/100, 42.23s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 92/100, 41.44s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 93/100, 41.07s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 94/100, 41.65s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 95/100, 43.26s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 96/100, 45.14s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 97/100, 46.60s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 98/100, 47.54s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# Epoch: 99/100, 40.52s/epoch, d_loss mean: -0.01990, g_loss mean: 4.60517
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-550860f133ba> in <module>()
#     219
#     220 en_time = time.time()
# --> 221 total_ptime = end_time - start_time
#     222 train_hist['total_ptime'].append(total_ptime)
#     223
#
# NameError: name 'end_time' is not defined

# %%
# Out:
# 1530520172.348708

# %%
import os, time, itertools, imageio, pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# G(z)
def generator(x):
    # initializers
    w_init = tf.truncated_normal_initializer(mean=0, stddev=0.02)
    b_init = tf.constant_initializer(0.)

    # 1st hidden layer
    w0 = tf.get_variable('G_w0', [x.get_shape()[1], 256], initializer=w_init)
    b0 = tf.get_variable('G_b0', [256], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)

    # 2nd hidden layer
    w1 = tf.get_variable('G_w1', [h0.get_shape()[1], 512], initializer=w_init)
    b1 = tf.get_variable('G_b1', [512], initializer=b_init)
    h1 = tf.nn.relu(tf.matmul(h0, w1) + b1)

    # 3rd hidden layer
    w2 = tf.get_variable('G_w2', [h1.get_shape()[1], 1024], initializer=w_init)
    b2 = tf.get_variable('G_b2', [1024], initializer=b_init)
    h2 = tf.nn.relu(tf.matmul(h1, w2) + b2)

    # output hidden layer
    w3 = tf.get_variable('G_w3', [h2.get_shape()[1], 784], initializer=w_init)
    b3 = tf.get_variable('G_b3', [784], initializer=b_init)
    o = tf.nn.tanh(tf.matmul(h2, w3) + b3)

    return o

# D(x)
def discriminator(x, drop_out):

    # initializers
    w_init = tf.truncated_normal_initializer(mean=0, stddev=0.02)
    b_init = tf.constant_initializer(0.)

    # 1st hidden layer
    w0 = tf.get_variable('D_w0', [x.get_shape()[1], 1024], initializer=w_init)
    b0 = tf.get_variable('D_b0', [1024], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)
    h0 = tf.nn.dropout(h0, drop_out)

    # 2nd hidden layer
    w1 = tf.get_variable('D_w1', [h0.get_shape()[1], 512], initializer=w_init)
    b1 = tf.get_variable('D_b1', [512], initializer=b_init)
    h1 = tf.nn.relu(tf.matmul(h0, w1) + b1)
    h1 = tf.nn.dropout(h1, drop_out)

    # 3rd hidden layer
    w2 = tf.get_variable('D_w2', [h1.get_shape()[1], 256], initializer=w_init)
    b2 = tf.get_variable('D_b2', [256], initializer=b_init)
    h2 = tf.nn.relu(tf.matmul(h1, w2) + b2)
    h2 = tf.nn.dropout(h2, drop_out)

    # output layer
    w3 = tf.get_variable('D_w3', [h2.get_shape()[1], 1], initializer=w_init)
    b3 = tf.get_variable('D_b3', [1], initializer=b_init)
    o = tf.sigmoid(tf.matmul(h2, w3) + b3)

    return o

fixed_z_ = np.random.normal(0, 1, (25, 100))
def show_result(num_epoch, show = False, save = False, path = 'result.png', isFix=False):
    z_ = np.random.normal(0, 1, (25, 100))

    if isFix:
        test_images = sess.run(G_z, {z: fixed_z_, drop_out: 0.0})
    else:
        test_images = sess.run(G_z, {z: z_, drop_out: 0.0})

    size_figure_grid = 5
    fig, ax = plt.subplots(size_figure_grid, size_figure_grid, figsize=(5, 5))
    for i, j in itertools.product(range(size_figure_grid), range(size_figure_grid)):
        ax[i, j].get_xaxis().set_visible(False)
        ax[i, j].get_yaxis().set_visible(False)

    for k in range(5*5):
        i = k // 5
        j = k % 5
        ax[i, j].cla()
        ax[i, j].imshow(np.reshape(test_images[k], (28, 28)), cmap='gray')

    label = 'Epoch {0}'.format(num_epoch)
    fig.text(0.5, 0.04, label, ha='center')
    plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()

def show_train_hist(hist, show = False, save = False, path = 'Train_hist.png'):
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()

# training parameters
batch_size = 100
lr = 0.0002
train_epoch = 100

# load MNIST
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
train_set = (mnist.train.images - 0.5) / 0.5  # normalization; range: -1 ~ 1

# networks : generator
with tf.variable_scope('G'):
    z = tf.placeholder(tf.float32, shape=(None, 100))
    G_z = generator(z)

# networks : discriminator
with tf.variable_scope('D') as scope:
    drop_out = tf.placeholder(dtype=tf.float32, name='drop_out')
    x = tf.placeholder(tf.float32, shape=(None, 784))
    D_real = discriminator(x, drop_out)
    scope.reuse_variables()
    D_fake = discriminator(G_z, drop_out)


# loss for each network
eps = 1e-2
D_loss = tf.reduce_mean(-tf.log(D_real + eps) - tf.log(1 - D_fake + eps))
G_loss = tf.reduce_mean(-tf.log(D_fake + eps))

# trainable variables for each network
t_vars = tf.trainable_variables()
D_vars = [var for var in t_vars if 'D_' in var.name]
G_vars = [var for var in t_vars if 'G_' in var.name]

# optimizer for each network
D_optim = tf.train.AdamOptimizer(lr).minimize(D_loss, var_list=D_vars)
G_optim = tf.train.AdamOptimizer(lr).minimize(G_loss, var_list=G_vars)

# open session and initialize all variables
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()

# results save folder
if not os.path.isdir('MNIST_GAN_results'):
    os.mkdir('MNIST_GAN_results')
if not os.path.isdir('MNIST_GAN_results/Random_results'):
    os.mkdir('MNIST_GAN_results/Random_results')
if not os.path.isdir('MNIST_GAN_results/Fixed_results'):
    os.mkdir('MNIST_GAN_results/Fixed_results')

train_hist = {}
train_hist['D_losses'] = []
train_hist['G_losses'] = []
train_hist['per_epoch_ptimes'] = []
train_hist['total_ptime'] = []

# training-loop
np.random.seed(int(time.time()))
start_time = time.time()
for epoch in range(train_epoch):
    G_losses = []
    D_losses = []
    epoch_start_time = time.time()
    for iter in range(train_set.shape[0] // batch_size):
        # update discriminator
        x_ = train_set[iter*batch_size:(iter+1)*batch_size]
        z_ = np.random.normal(0, 1, (batch_size, 100))

        loss_d_, _ = sess.run([D_loss, D_optim], {x: x_, z: z_, drop_out: 0.3})
        D_losses.append(loss_d_)

        # update generator
        z_ = np.random.normal(0, 1, (batch_size, 100))
        loss_g_, _ = sess.run([G_loss, G_optim], {z: z_, drop_out: 0.3})
        G_losses.append(loss_g_)

    epoch_end_time = time.time()
    per_epoch_ptime = epoch_end_time - epoch_start_time
    print('[%d/%d] - ptime: %.2f loss_d: %.3f, loss_g: %.3f' % ((epoch + 1), train_epoch, per_epoch_ptime, np.mean(D_losses), np.mean(G_losses)))
    p = 'MNIST_GAN_results/Random_results/MNIST_GAN_' + str(epoch + 1) + '.png'
    fixed_p = 'MNIST_GAN_results/Fixed_results/MNIST_GAN_' + str(epoch + 1) + '.png'
    show_result((epoch + 1), save=True, path=p, isFix=False)
    show_result((epoch + 1), save=True, path=fixed_p, isFix=True)
    train_hist['D_losses'].append(np.mean(D_losses))
    train_hist['G_losses'].append(np.mean(G_losses))
    train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

end_time = time.time()
total_ptime = end_time - start_time
train_hist['total_ptime'].append(total_ptime)

print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (np.mean(train_hist['per_epoch_ptimes']), train_epoch, total_ptime))
print("Training finish!... save training results")
with open('MNIST_GAN_results/train_hist.pkl', 'wb') as f:
    pickle.dump(train_hist, f)
show_train_hist(train_hist, save=True, path='MNIST_GAN_results/MNIST_GAN_train_hist.png')

images = []
for e in range(train_epoch):
    img_name = 'MNIST_GAN_results/Fixed_results/MNIST_GAN_' + str(e + 1) + '.png'
    images.append(imageio.imread(img_name))
imageio.mimsave('MNIST_GAN_results/generation_animation.gif', images, fps=5)

sess.close()
# Out:
# WARNING:tensorflow:From <ipython-input-1-4216f1169cd1>:127: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/victor/virtualenvlist/mydlp2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: __init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# [1/100] - ptime: 38.53 loss_d: 0.744, loss_g: 1.523
# [2/100] - ptime: 40.43 loss_d: 0.305, loss_g: 2.832
# [3/100] - ptime: 36.36 loss_d: 0.511, loss_g: 2.212
# [4/100] - ptime: 37.50 loss_d: 0.503, loss_g: 2.150
# [5/100] - ptime: 38.93 loss_d: 0.555, loss_g: 2.169
# [6/100] - ptime: 43.30 loss_d: 0.725, loss_g: 1.742
# [7/100] - ptime: 43.11 loss_d: 0.742, loss_g: 1.556
# [8/100] - ptime: 42.43 loss_d: 0.706, loss_g: 1.674
# [9/100] - ptime: 39.14 loss_d: 0.715, loss_g: 1.817
# [10/100] - ptime: 37.36 loss_d: 0.881, loss_g: 1.408
# [11/100] - ptime: 36.48 loss_d: 0.954, loss_g: 1.278
# [12/100] - ptime: 39.18 loss_d: 0.966, loss_g: 1.260
# [13/100] - ptime: 39.19 loss_d: 1.053, loss_g: 1.118
# [14/100] - ptime: 38.29 loss_d: 1.108, loss_g: 0.985
# [15/100] - ptime: 42.89 loss_d: 1.144, loss_g: 0.955
# [16/100] - ptime: 41.06 loss_d: 1.145, loss_g: 0.952
# [17/100] - ptime: 40.34 loss_d: 1.114, loss_g: 0.995
# [18/100] - ptime: 43.24 loss_d: 1.143, loss_g: 0.972
# [19/100] - ptime: 41.90 loss_d: 1.189, loss_g: 0.919
# [20/100] - ptime: 39.78 loss_d: 1.178, loss_g: 0.895
# [21/100] - ptime: 43.54 loss_d: 1.179, loss_g: 0.918
# [22/100] - ptime: 39.44 loss_d: 1.182, loss_g: 0.930
# [23/100] - ptime: 41.50 loss_d: 1.201, loss_g: 0.879
# [24/100] - ptime: 43.63 loss_d: 1.182, loss_g: 0.918
# [25/100] - ptime: 45.51 loss_d: 1.195, loss_g: 0.877
# [26/100] - ptime: 42.14 loss_d: 1.193, loss_g: 0.897
# [27/100] - ptime: 40.76 loss_d: 1.178, loss_g: 0.906
# [28/100] - ptime: 40.87 loss_d: 1.216, loss_g: 0.879
# [29/100] - ptime: 42.71 loss_d: 1.196, loss_g: 0.904
# [30/100] - ptime: 42.97 loss_d: 1.177, loss_g: 0.894
# [31/100] - ptime: 41.46 loss_d: 1.186, loss_g: 0.928
# [32/100] - ptime: 45.96 loss_d: 1.224, loss_g: 0.846
# [33/100] - ptime: 43.28 loss_d: 1.225, loss_g: 0.839
# [34/100] - ptime: 46.22 loss_d: 1.254, loss_g: 0.839
# [35/100] - ptime: 39.29 loss_d: 1.250, loss_g: 0.793
# [36/100] - ptime: 45.65 loss_d: 1.242, loss_g: 0.816
# [37/100] - ptime: 39.27 loss_d: 1.262, loss_g: 0.801
# [38/100] - ptime: 38.18 loss_d: 1.258, loss_g: 0.831
# [39/100] - ptime: 38.28 loss_d: 1.260, loss_g: 0.778
# [40/100] - ptime: 38.28 loss_d: 1.285, loss_g: 0.778
# [41/100] - ptime: 38.40 loss_d: 1.261, loss_g: 0.805
# [42/100] - ptime: 38.57 loss_d: 1.261, loss_g: 0.804
# [43/100] - ptime: 40.56 loss_d: 1.288, loss_g: 0.769
# [44/100] - ptime: 38.20 loss_d: 1.305, loss_g: 0.750
# [45/100] - ptime: 38.39 loss_d: 1.284, loss_g: 0.756
# [46/100] - ptime: 38.37 loss_d: 1.306, loss_g: 0.733
# [47/100] - ptime: 38.32 loss_d: 1.287, loss_g: 0.750
# [48/100] - ptime: 38.27 loss_d: 1.302, loss_g: 0.749
# [49/100] - ptime: 38.07 loss_d: 1.296, loss_g: 0.754
# [50/100] - ptime: 38.09 loss_d: 1.301, loss_g: 0.757
# [51/100] - ptime: 37.94 loss_d: 1.286, loss_g: 0.768
# [52/100] - ptime: 38.05 loss_d: 1.291, loss_g: 0.745
# [53/100] - ptime: 38.11 loss_d: 1.315, loss_g: 0.732
# [54/100] - ptime: 38.15 loss_d: 1.306, loss_g: 0.738
# [55/100] - ptime: 38.17 loss_d: 1.310, loss_g: 0.736
# [56/100] - ptime: 38.14 loss_d: 1.304, loss_g: 0.726
# [57/100] - ptime: 38.09 loss_d: 1.291, loss_g: 0.766
# [58/100] - ptime: 38.13 loss_d: 1.291, loss_g: 0.745
# [59/100] - ptime: 38.74 loss_d: 1.281, loss_g: 0.778
# [60/100] - ptime: 46.78 loss_d: 1.299, loss_g: 0.754
# [61/100] - ptime: 45.95 loss_d: 1.305, loss_g: 0.737
# [62/100] - ptime: 44.68 loss_d: 1.285, loss_g: 0.766
# [63/100] - ptime: 43.45 loss_d: 1.292, loss_g: 0.756
# [64/100] - ptime: 44.03 loss_d: 1.307, loss_g: 0.746
# [65/100] - ptime: 42.89 loss_d: 1.313, loss_g: 0.731
# [66/100] - ptime: 43.82 loss_d: 1.315, loss_g: 0.721
# [67/100] - ptime: 44.36 loss_d: 1.316, loss_g: 0.724
# [68/100] - ptime: 45.15 loss_d: 1.314, loss_g: 0.723
# [69/100] - ptime: 44.22 loss_d: 1.310, loss_g: 0.733
# [70/100] - ptime: 45.50 loss_d: 1.306, loss_g: 0.740
# [71/100] - ptime: 43.11 loss_d: 1.317, loss_g: 0.720
# [72/100] - ptime: 43.80 loss_d: 1.310, loss_g: 0.735
# [73/100] - ptime: 40.79 loss_d: 1.317, loss_g: 0.727
# [74/100] - ptime: 43.88 loss_d: 1.305, loss_g: 0.732
# [75/100] - ptime: 46.64 loss_d: 1.305, loss_g: 0.735
# [76/100] - ptime: 46.66 loss_d: 1.311, loss_g: 0.732
# [77/100] - ptime: 46.63 loss_d: 1.329, loss_g: 0.712
# [78/100] - ptime: 49.00 loss_d: 1.325, loss_g: 0.719
# [79/100] - ptime: 46.51 loss_d: 1.319, loss_g: 0.716
# [80/100] - ptime: 47.40 loss_d: 1.322, loss_g: 0.709
# [81/100] - ptime: 48.20 loss_d: 1.322, loss_g: 0.712
# [82/100] - ptime: 48.85 loss_d: 1.315, loss_g: 0.726
# [83/100] - ptime: 48.84 loss_d: 1.312, loss_g: 0.731
# [84/100] - ptime: 47.79 loss_d: 1.312, loss_g: 0.724
# [85/100] - ptime: 50.19 loss_d: 1.311, loss_g: 0.732
# [86/100] - ptime: 49.38 loss_d: 1.328, loss_g: 0.711
# [87/100] - ptime: 42.88 loss_d: 1.322, loss_g: 0.717
# [88/100] - ptime: 41.27 loss_d: 1.313, loss_g: 0.716
# [89/100] - ptime: 50.18 loss_d: 1.327, loss_g: 0.710
# [90/100] - ptime: 53.32 loss_d: 1.322, loss_g: 0.722
# [91/100] - ptime: 50.12 loss_d: 1.317, loss_g: 0.718
# [92/100] - ptime: 47.57 loss_d: 1.320, loss_g: 0.721
# [93/100] - ptime: 48.81 loss_d: 1.319, loss_g: 0.723
# [94/100] - ptime: 47.42 loss_d: 1.320, loss_g: 0.713
# [95/100] - ptime: 50.43 loss_d: 1.326, loss_g: 0.716
# [96/100] - ptime: 47.58 loss_d: 1.332, loss_g: 0.695
# [97/100] - ptime: 45.85 loss_d: 1.334, loss_g: 0.696
# [98/100] - ptime: 44.03 loss_d: 1.333, loss_g: 0.703
# [99/100] - ptime: 43.02 loss_d: 1.322, loss_g: 0.712
# [100/100] - ptime: 41.60 loss_d: 1.332, loss_g: 0.699
# Avg per epoch ptime: 42.60, total 100 epochs ptime: 4482.48
# Training finish!... save training results
