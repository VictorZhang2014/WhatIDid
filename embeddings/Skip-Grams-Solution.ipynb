# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:07, 246KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    
    summary_merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter('graph/train', sess.graph)
    
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
    train_writer.close()
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6866 0.0517 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6318 0.0508 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5101 0.0512 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5879 0.0506 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5255 0.0506 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5705 0.0506 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5394 0.0505 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5342 0.0507 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4598 0.0509 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4235 0.0509 sec/batch
# Nearest to during: workout, gunner, weather, cathari, ahead, microbats, delays, often,
# Nearest to four: insider, ingested, magician, delineate, squeeze, samosata, blazing, lobby,
# Nearest to use: directed, thrived, demme, bioko, almost, motionless, formalizing, bitrates,
# Nearest to from: societas, ethnic, hallertau, composes, subsistence, transition, spiraling, clocked,
# Nearest to years: phone, aspirated, fairway, consensual, caracalla, mothering, gehrig, preoccupation,
# Nearest to b: ellensburg, diagnosing, dodd, jellicoe, bulkier, universally, casinos, mononobe,
# Nearest to however: nigerians, palmerston, extroverted, phytoplankton, trustees, wipes, promised, versace,
# Nearest to would: polish, steered, throws, tribes, contaminants, deniability, singularities, refutable,
# Nearest to hit: justifications, battleship, anc, sidekick, prc, numeric, tap, dharmic,
# Nearest to mean: hanun, reconnection, retaken, vox, familes, me, boyband, expedited,
# Nearest to bbc: krylov, spiritus, overlords, buckyballs, email, quiver, thenceforth, anymore,
# Nearest to channel: summarizes, daniele, gamete, loglan, gunned, bsi, colossal, minerva,
# Nearest to experience: auc, mammalian, cru, conservatoire, gras, maupin, gladiators, chinensis,
# Nearest to heavy: cer, eurocheque, orchestral, haa, manatee, wakefulness, departments, throat,
# Nearest to quite: succinic, dkp, kitzmiller, jacksonian, duke, ushant, expecting, sterreich,
# Nearest to centre: annotate, northernmost, absalon, solo, umkehrwalze, owens, plagued, depalma,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4611 0.0521 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4054 0.0506 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3214 0.0507 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2338 0.0506 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1983 0.0508 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1570 0.0508 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0876 0.0506 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0429 0.0508 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0073 0.0506 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9761 0.0507 sec/batch
# Nearest to during: his, often, weather, ahead, workout, delays, moreover, expected,
# Nearest to four: insider, magician, one, delineate, blazing, ingested, cheney, squeeze,
# Nearest to use: directed, almost, longer, thrived, probable, demme, its, formalizing,
# Nearest to from: ethnic, nuclear, transition, concept, societas, feeling, fed, f,
# Nearest to years: life, phone, preoccupation, consensual, caracalla, kittyhawk, aspirated, fairway,
# Nearest to b: ellensburg, diagnosing, universally, jellicoe, mononobe, dodd, aedh, bulkier,
# Nearest to however: promised, search, nigerians, trustees, palmerston, introductory, responsible, should,
# Nearest to would: polish, steered, tribes, publish, language, saving, pp, throws,
# Nearest to hit: justifications, battleship, numeric, anc, prc, sidekick, measure, dharmic,
# Nearest to mean: me, hanun, sun, familes, solely, overlap, reconnection, retaken,
# Nearest to bbc: krylov, email, spiritus, overlords, buckyballs, quiver, anymore, burgh,
# Nearest to channel: gamete, daniele, summarizes, deliver, jamaica, minerva, bsi, bug,
# Nearest to experience: mammalian, auc, gras, cru, precisely, conservatoire, works, organization,
# Nearest to heavy: cer, eurocheque, departments, orchestral, throat, irenaeus, statewide, haa,
# Nearest to quite: duke, succinic, briefly, relating, expecting, difficult, learning, about,
# Nearest to centre: annotate, northernmost, solo, absalon, apostle, plagued, umkehrwalze, journeys,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9407 0.0516 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8825 0.0509 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8931 0.0507 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8406 0.0506 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8093 0.0503 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8177 0.0507 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7999 0.0508 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7743 0.0506 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7950 0.0507 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7875 0.0507 sec/batch
# Nearest to during: weather, workout, his, moreover, delays, ahead, expected, often,
# Nearest to four: one, magician, cheney, insider, summary, delineate, invocation, lobby,
# Nearest to use: directed, thrived, longer, yours, almost, probable, demme, bioko,
# Nearest to from: ethnic, subsistence, fed, nuclear, societas, glen, incantations, composes,
# Nearest to years: life, preoccupation, hostility, consensual, fairway, conclusively, smuggled, aspirated,
# Nearest to b: diagnosing, ellensburg, aedh, universally, dodd, mononobe, succeed, bulkier,
# Nearest to however: promised, nigerians, trustees, search, commission, palmerston, retiring, formulae,
# Nearest to would: steered, polish, saving, tribes, criterion, beneficial, publish, warner,
# Nearest to hit: justifications, numeric, tap, prc, battleship, anc, sidekick, dharmic,
# Nearest to mean: overlap, me, familes, sun, mate, hanun, reconnection, retaken,
# Nearest to bbc: email, spiritus, krylov, anymore, overlords, buckyballs, quiver, britons,
# Nearest to channel: gamete, summarizes, daniele, deliver, funding, gunned, jamaica, minerva,
# Nearest to experience: mammalian, auc, gras, conservatoire, cru, precisely, cooperative, gladiators,
# Nearest to heavy: departments, orchestral, eurocheque, cer, prussian, throat, irenaeus, statewide,
# Nearest to quite: unicameral, succinic, duke, expecting, remembered, laborer, temples, briefly,
# Nearest to centre: annotate, northernmost, solo, plagued, absalon, journeys, apostle, weren,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7608 0.0518 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7605 0.0506 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7143 0.0505 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7129 0.0505 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7209 0.0509 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6962 0.0507 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6998 0.0505 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7624 0.0508 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7025 0.0510 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6709 0.0507 sec/batch
# Nearest to during: workout, weather, his, delays, ahead, helped, gunner, cathari,
# Nearest to four: one, magician, cheney, charles, reunite, m, six, invocation,
# Nearest to use: thrived, longer, directed, yours, almost, demme, referential, bioko,
# Nearest to from: subsistence, ethnic, glen, fed, composes, hallertau, incantations, nuclear,
# Nearest to years: life, preoccupation, smuggled, consensual, fairway, conclusively, hostility, berkeley,
# Nearest to b: diagnosing, aedh, mononobe, eight, keillor, ellensburg, succeed, florence,
# Nearest to however: nigerians, promised, trustees, palmerston, retiring, illegitimate, formulae, coffee,
# Nearest to would: steered, criterion, polish, saving, beneficial, throws, transitions, tribes,
# Nearest to hit: justifications, tap, battleship, anc, prc, numeric, sidekick, elmira,
# Nearest to mean: overlap, hanun, familes, me, retaken, sun, reconnection, solely,
# Nearest to bbc: email, krylov, overlords, spiritus, anymore, buckyballs, marina, quiver,
# Nearest to channel: gamete, daniele, summarizes, gunned, colossal, loglan, deliver, bsi,
# Nearest to experience: auc, mammalian, gras, cru, conservatoire, maupin, amboise, respectful,
# Nearest to heavy: orchestral, departments, cer, eurocheque, throat, irenaeus, prussian, statewide,
# Nearest to quite: succinic, unicameral, royale, expecting, jacksonian, laborer, temples, precluded,
# Nearest to centre: annotate, northernmost, absalon, plagued, journeys, solo, umkehrwalze, depalma,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6687 0.0513 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6693 0.0507 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6218 0.0507 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6424 0.0509 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6189 0.0505 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6351 0.0505 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6088 0.0378 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5788 0.0508 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5203 0.0508 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4931 0.0511 sec/batch
# Nearest to during: workout, weather, his, ahead, delays, cathari, gunner, helped,
# Nearest to four: one, charles, six, magician, zero, heinrich, cheney, punjabi,
# Nearest to use: longer, thrived, yours, directed, categorizing, almost, informatics, sinners,
# Nearest to from: subsistence, ethnic, glen, fed, hallertau, composes, stemmed, friars,
# Nearest to years: life, preoccupation, smuggled, consensual, fairway, conclusively, ogre, del,
# Nearest to b: diagnosing, writer, eight, william, five, henri, nine, keillor,
# Nearest to however: nigerians, promised, trustees, palmerston, plank, phytoplankton, extroverted, coffee,
# Nearest to would: steered, criterion, saving, beneficial, throws, polish, deniability, invocation,
# Nearest to hit: justifications, tap, battleship, prc, anc, numeric, sidekick, elmira,
# Nearest to mean: overlap, hanun, solely, reconnection, familes, retaken, me, acronym,
# Nearest to bbc: overlords, marina, spiritus, buckyballs, email, krylov, anymore, thorne,
# Nearest to channel: gamete, daniele, summarizes, colossal, loglan, gunned, minerva, bsi,
# Nearest to experience: auc, maupin, mammalian, conservatoire, cru, gras, respectful, amboise,
# Nearest to heavy: orchestral, throat, cer, eurocheque, departments, irenaeus, manatee, statewide,
# Nearest to quite: succinic, unicameral, royale, precluded, purists, expecting, because, temples,
# Nearest to centre: annotate, absalon, northernmost, plagued, journeys, depalma, umkehrwalze, owens,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4873 0.0517 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4834 0.0505 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4801 0.0505 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5226 0.0507 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4995 0.0506 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4620 0.0504 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4799 0.0506 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4104 0.0508 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4363 0.0506 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4303 0.0506 sec/batch
# Nearest to during: workout, his, weather, ahead, delays, gunner, helped, welch,
# Nearest to four: one, six, zero, m, three, airing, magician, two,
# Nearest to use: longer, yours, thrived, involve, its, categorizing, almost, informatics,
# Nearest to from: subsistence, fed, ethnic, composes, hallertau, friars, stemmed, glen,
# Nearest to years: life, female, preoccupation, consensual, smuggled, fairway, andechs, conclusively,
# Nearest to b: diagnosing, william, entertainer, florence, aedh, mononobe, writer, keillor,
# Nearest to however: promised, nigerians, trustees, palmerston, plank, extroverted, deform, versace,
# Nearest to would: throws, steered, criterion, saving, polish, beneficial, installed, deniability,
# Nearest to hit: tap, justifications, sidekick, prc, elmira, battleship, anc, numeric,
# Nearest to mean: hanun, overlap, solely, reconnection, sun, familes, retaken, me,
# Nearest to bbc: email, truer, marina, krylov, spiritus, vh, director, britons,
# Nearest to channel: daniele, gamete, gunned, summarizes, loglan, colossal, minerva, helicopter,
# Nearest to experience: auc, cru, mammalian, maupin, precisely, gras, conservatoire, respectful,
# Nearest to heavy: orchestral, throat, cer, statewide, manatee, departments, eurocheque, irenaeus,
# Nearest to quite: succinic, precluded, royale, purists, jpl, because, expecting, temples,
# Nearest to centre: annotate, northernmost, absalon, plagued, journeys, umkehrwalze, occupied, owens,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4505 0.0516 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4015 0.0511 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4197 0.0505 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3883 0.0508 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4314 0.0506 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4456 0.0507 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3760 0.0507 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3958 0.0507 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4128 0.0507 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3637 0.0508 sec/batch
# Nearest to during: workout, his, weather, ahead, gunner, helped, delays, crimean,
# Nearest to four: one, six, zero, three, two, m, five, per,
# Nearest to use: longer, thrived, almost, referential, its, bioko, yours, demme,
# Nearest to from: subsistence, ethnic, friars, fed, hallertau, composes, societas, stemmed,
# Nearest to years: life, female, preoccupation, consensual, fairway, andechs, conclusively, kittyhawk,
# Nearest to b: diagnosing, william, entertainer, florence, writer, aedh, henri, eight,
# Nearest to however: promised, nigerians, palmerston, deform, trustees, extroverted, wipes, plank,
# Nearest to would: throws, criterion, saving, steered, installed, polish, beneficial, pashtunistan,
# Nearest to hit: tap, sidekick, elmira, justifications, prc, picked, anc, battleship,
# Nearest to mean: hanun, overlap, reconnection, solely, homeomorphisms, familes, acronym, inserts,
# Nearest to bbc: truer, email, brigid, marina, britons, krylov, thorne, director,
# Nearest to channel: daniele, gamete, loglan, summarizes, gunned, helicopter, deliver, minerva,
# Nearest to experience: cru, auc, maupin, precisely, mammalian, conservatoire, respectful, gras,
# Nearest to heavy: orchestral, eurocheque, statewide, throat, manatee, cer, registered, supercar,
# Nearest to quite: succinic, jpl, royale, purists, precluded, expecting, exoplanets, difficult,
# Nearest to centre: annotate, northernmost, absalon, plagued, umkehrwalze, journeys, battalions, occupied,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3676 0.0513 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3545 0.0505 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3456 0.0507 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3750 0.0508 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3849 0.0506 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3593 0.0507 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3608 0.0512 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3814 0.0508 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3340 0.0505 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3363 0.0505 sec/batch
# Nearest to during: workout, weather, ahead, his, gunner, delays, mongol, helped,
# Nearest to four: one, six, zero, three, two, m, five, per,
# Nearest to use: longer, thrived, almost, its, referential, demme, bioko, yours,
# Nearest to from: subsistence, ethnic, friars, stemmed, composes, berbers, exactions, societas,
# Nearest to years: life, female, ogre, consensual, fairway, preoccupation, kittyhawk, andechs,
# Nearest to b: diagnosing, aedh, william, entertainer, florence, scribner, calculus, writer,
# Nearest to however: nigerians, promised, deform, trustees, palmerston, extroverted, plank, wipes,
# Nearest to would: throws, saving, steered, criterion, installed, polish, refutable, pashtunistan,
# Nearest to hit: tap, sidekick, elmira, picked, battleship, got, anc, justifications,
# Nearest to mean: hanun, overlap, reconnection, homeomorphisms, solely, familes, sun, acronym,
# Nearest to bbc: truer, email, brigid, britons, spiritus, thorne, marina, mightiest,
# Nearest to channel: daniele, loglan, gamete, gunned, deliver, summarizes, cve, colossal,
# Nearest to experience: cru, auc, maupin, conservatoire, respectful, mammalian, gladiators, gras,
# Nearest to heavy: orchestral, registered, cer, rectifiers, throat, statewide, supercar, manatee,
# Nearest to quite: succinic, purists, expecting, exoplanets, jpl, because, royale, temples,
# Nearest to centre: annotate, plagued, northernmost, umkehrwalze, absalon, journeys, battalions, leonidas,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3263 0.0520 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3047 0.0510 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3879 0.0508 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3896 0.0504 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3764 0.0506 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2890 0.0510 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2789 0.0502 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3230 0.0507 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2052 0.0505 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3186 0.0508 sec/batch
# Nearest to during: workout, weather, his, gunner, ahead, mongol, crimean, amusements,
# Nearest to four: one, three, zero, six, two, five, m, per,
# Nearest to use: thrived, longer, referential, its, informatics, bioko, demme, almost,
# Nearest to from: subsistence, friars, ethnic, stemmed, composes, berbers, societas, slave,
# Nearest to years: female, life, male, andechs, four, ogre, consensual, migrant,
# Nearest to b: diagnosing, william, eight, writer, entertainer, statesman, scribner, egon,
# Nearest to however: promised, nigerians, trustees, deform, palmerston, extroverted, wipes, plank,
# Nearest to would: throws, saving, steered, installed, criterion, pashtunistan, mgh, understandably,
# Nearest to hit: tap, sidekick, got, picked, elmira, battleship, filmography, justifications,
# Nearest to mean: hanun, overlap, homeomorphisms, reconnection, familes, solely, acronym, inserts,
# Nearest to bbc: truer, email, brigid, marina, mightiest, spiritus, alys, britons,
# Nearest to channel: daniele, loglan, gamete, colossal, rebranding, helicopter, habermas, gunned,
# Nearest to experience: cru, auc, maupin, conservatoire, think, respectful, mammalian, gras,
# Nearest to heavy: orchestral, rectifiers, white, spoon, dystopian, throat, manatee, registered,
# Nearest to quite: succinic, expecting, royale, jpl, purists, because, variety, temples,
# Nearest to centre: northernmost, plagued, annotate, umkehrwalze, absalon, journeys, metro, leonidas,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3085 0.0516 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2920 0.0506 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3317 0.0247 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2329 0.0506 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2246 0.0508 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1993 0.0509 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2291 0.0509 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2303 0.0512 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2163 0.0507 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2001 0.0506 sec/batch
# Nearest to during: weather, workout, gunner, ahead, his, mongol, amusements, crimean,
# Nearest to four: one, three, six, zero, five, two, m, per,
# Nearest to use: thrived, demme, longer, its, informatics, bioko, referential, directed,
# Nearest to from: friars, subsistence, stemmed, ethnic, inexact, hallertau, berbers, composes,
# Nearest to years: female, life, male, four, consensual, household, householder, migrant,
# Nearest to b: diagnosing, egon, william, writer, statesman, entertainer, eight, calculus,
# Nearest to however: promised, nigerians, trustees, deform, eisenberg, palmerston, extroverted, wipes,
# Nearest to would: throws, saving, criterion, steered, installed, mgh, understandably, deniability,
# Nearest to hit: tap, got, picked, sidekick, hitting, elmira, battleship, furnace,
# Nearest to mean: hanun, homeomorphisms, reconnection, overlap, familes, solely, acronym, vox,
# Nearest to bbc: truer, email, brigid, marina, astrologically, mightiest, alys, hot,
# Nearest to channel: loglan, daniele, gamete, colossal, habermas, helicopter, rebranding, bug,
# Nearest to experience: cru, maupin, think, auc, respectful, mammalian, gras, conservatoire,
# Nearest to heavy: orchestral, rectifiers, supercar, white, registered, manatee, spoon, throat,
# Nearest to quite: succinic, royale, expecting, purists, precluded, dkp, variety, because,
# Nearest to centre: metro, northernmost, plagued, umkehrwalze, annotate, absalon, journeys, owens,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2543 0.0518 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2193 0.0505 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2328 0.0506 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1508 0.0508 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1655 0.0506 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1888 0.0510 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1849 0.0502 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1800 0.0504 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2107 0.0507 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1611 0.0504 sec/batch
# Nearest to during: workout, weather, gunner, ahead, his, crimean, mongol, amusements,
# Nearest to four: one, three, six, zero, two, five, m, years,
# Nearest to use: thrived, demme, longer, its, bioko, directed, staphylococcus, referential,
# Nearest to from: subsistence, friars, inexact, ethnic, stemmed, hallertau, fed, pine,
# Nearest to years: female, life, four, householder, male, household, deaths, migrant,
# Nearest to b: diagnosing, iterations, calculus, egon, william, aedh, transliterating, algebraic,
# Nearest to however: promised, nigerians, extroverted, deform, wipes, trustees, palmerston, eisenberg,
# Nearest to would: throws, steered, saving, installed, criterion, deniability, understandably, hewson,
# Nearest to hit: tap, got, hitting, sidekick, picked, elmira, furnace, battleship,
# Nearest to mean: hanun, reconnection, homeomorphisms, overlap, familes, solely, vox, acronym,
# Nearest to bbc: truer, email, brigid, broadcast, astrologically, dvds, hot, allowing,
# Nearest to channel: daniele, loglan, bug, helicopter, cve, colossal, habermas, litchfield,
# Nearest to experience: cru, think, respectful, auc, maupin, gras, tellurium, mammalian,
# Nearest to heavy: rectifiers, orchestral, registered, manatee, spoon, supercar, linebacker, white,
# Nearest to quite: succinic, expecting, purists, royale, precluded, loaf, asher, dkp,
# Nearest to centre: metro, umkehrwalze, northernmost, absalon, journeys, plagued, wall, annotate,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2057 0.0514 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2401 0.0505 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1682 0.0507 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1521 0.0502 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1732 0.0504 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1970 0.0505 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2297 0.0505 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1658 0.0503 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1504 0.0506 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1640 0.0506 sec/batch
# Nearest to during: workout, weather, gunner, ahead, crimean, mongol, helped, amusements,
# Nearest to four: one, three, six, two, zero, five, years, m,
# Nearest to use: thrived, demme, directed, its, longer, cmt, bioko, informatics,
# Nearest to from: friars, subsistence, stemmed, xylophone, inexact, ethnic, alphabet, bulgars,
# Nearest to years: female, life, four, male, household, migrant, expectancy, householder,
# Nearest to b: diagnosing, william, calculus, writer, egon, iterations, aedh, elmer,
# Nearest to however: nigerians, promised, trustees, wipes, deform, lax, extroverted, eisenberg,
# Nearest to would: throws, steered, criterion, saving, installed, warner, deniability, unlawful,
# Nearest to hit: tap, got, hitting, picked, sidekick, elmira, furnace, battleship,
# Nearest to mean: hanun, reconnection, vox, familes, homeomorphisms, overlap, solely, acronym,
# Nearest to bbc: truer, email, brigid, broadcast, dvds, allowing, nights, astrologically,
# Nearest to channel: daniele, loglan, colossal, bug, habermas, cve, deliver, marysville,
# Nearest to experience: cru, think, respectful, auc, maupin, gras, tellurium, conservatoire,
# Nearest to heavy: rectifiers, orchestral, close, throat, registered, supercar, spoon, white,
# Nearest to quite: succinic, purists, royale, expecting, because, asher, precluded, unicameral,
# Nearest to centre: absalon, umkehrwalze, journeys, metro, wall, plagued, annotate, northernmost,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1880 0.0519 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1671 0.0508 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1961 0.0505 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1809 0.0508 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1519 0.0507 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1412 0.0505 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1505 0.0507 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1014 0.0510 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2113 0.0507 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2210 0.0505 sec/batch
# Nearest to during: weather, workout, mongol, gunner, crimean, ahead, helped, his,
# Nearest to four: one, three, six, zero, five, two, seven, years,
# Nearest to use: longer, thrived, its, directed, demme, cmt, staphylococcus, bioko,
# Nearest to from: friars, bulgars, berbers, slave, stemmed, exactions, xylophone, summon,
# Nearest to years: female, life, four, household, male, expectancy, zero, householder,
# Nearest to b: writer, egon, eight, william, scribner, moravia, elmer, diagnosing,
# Nearest to however: nigerians, trustees, promised, wipes, to, accusative, palmerston, eisenberg,
# Nearest to would: throws, criterion, steered, saving, meets, installed, unlawful, froggy,
# Nearest to hit: hitting, got, tap, picked, sidekick, elmira, battleship, henchman,
# Nearest to mean: hanun, reconnection, homeomorphisms, acronym, vox, familes, solely, overlap,
# Nearest to bbc: truer, email, brigid, astrologically, nights, marina, dvds, broadcast,
# Nearest to channel: daniele, loglan, colossal, bug, cve, habermas, deliver, bsi,
# Nearest to experience: cru, auc, gras, maupin, think, conservatoire, respectful, amboise,
# Nearest to heavy: rectifiers, orchestral, throat, registered, dystopian, manatee, supercar, white,
# Nearest to quite: succinic, purists, royale, expecting, asher, precluded, variety, masts,
# Nearest to centre: metro, absalon, wall, journeys, umkehrwalze, plagued, steamship, annotate,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2338 0.0514 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1367 0.0505 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1378 0.0502 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1520 0.0503 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0396 0.0504 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1187 0.0506 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1554 0.0506 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1370 0.0506 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1904 0.0117 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1197 0.0507 sec/batch
# Nearest to during: weather, workout, mongol, gunner, ahead, helped, amusements, crimean,
# Nearest to four: one, three, two, zero, six, five, years, seven,
# Nearest to use: directed, thrived, longer, its, demme, informatics, staphylococcus, used,
# Nearest to from: friars, the, berbers, stemmed, a, inexact, subsistence, bulgars,
# Nearest to years: female, life, household, four, male, householder, zero, migrant,
# Nearest to b: william, egon, calculus, moravia, scribner, diagnosing, iterations, writer,
# Nearest to however: nigerians, promised, wipes, trustees, devastation, accusative, to, palmerston,
# Nearest to would: throws, criterion, steered, saving, deniability, installed, understandably, bans,
# Nearest to hit: hitting, got, tap, picked, elmira, sidekick, battleship, henchman,
# Nearest to mean: hanun, reconnection, acronym, homeomorphisms, vox, coset, familes, solely,
# Nearest to bbc: truer, email, brigid, astrologically, nights, broadcast, mightiest, dvds,
# Nearest to channel: daniele, loglan, colossal, cve, bug, habermas, rebranding, deliver,
# Nearest to experience: cru, gras, think, maupin, auc, tellurium, respectful, polices,
# Nearest to heavy: rectifiers, orchestral, throat, dystopian, registered, manatee, white, spoon,
# Nearest to quite: royale, purists, succinic, precluded, expecting, variety, because, rstenberg,
# Nearest to centre: metro, absalon, wall, steamship, triumphal, umkehrwalze, journeys, plagued,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0763 0.0517 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1035 0.0507 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0962 0.0506 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0643 0.0505 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0766 0.0507 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0649 0.0506 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1102 0.0507 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0696 0.0505 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1226 0.0507 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0151 0.0507 sec/batch
# Nearest to during: weather, workout, mongol, gunner, helped, ahead, refuel, amusements,
# Nearest to four: one, three, six, two, five, zero, years, per,
# Nearest to use: longer, thrived, its, staphylococcus, demme, used, directed, cmt,
# Nearest to from: friars, the, xylophone, a, bulgars, berbers, stemmed, slave,
# Nearest to years: female, life, four, householder, household, male, deaths, zero,
# Nearest to b: iterations, moravia, diagnosing, calculus, egon, universally, aedh, scribner,
# Nearest to however: accusative, devastation, wipes, promised, nigerians, trustees, eisenberg, awe,
# Nearest to would: throws, steered, saving, criterion, installed, deniability, warner, hewson,
# Nearest to hit: hitting, tap, got, balls, picked, battleship, elmira, henchman,
# Nearest to mean: hanun, reconnection, homeomorphisms, vox, acronym, coset, me, inserts,
# Nearest to bbc: email, truer, brigid, broadcast, dvds, articles, april, listing,
# Nearest to channel: daniele, loglan, colossal, habermas, bug, cve, marysville, rebranding,
# Nearest to experience: cru, gras, maupin, auc, think, respectful, tellurium, quadrant,
# Nearest to heavy: rectifiers, orchestral, throat, registered, dystopian, white, manatee, supercar,
# Nearest to quite: precluded, royale, succinic, unicameral, purists, asher, occupy, expecting,
# Nearest to centre: metro, wall, absalon, steamship, northernmost, square, triumphal, journeys,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0095 0.0516 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0400 0.0506 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0229 0.0505 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0444 0.0505 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0750 0.0507 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0141 0.0505 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0604 0.0511 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1057 0.0516 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0483 0.0508 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0621 0.0507 sec/batch
# Nearest to during: workout, weather, gunner, helped, amusements, mongol, ahead, refuel,
# Nearest to four: one, three, five, two, six, zero, years, total,
# Nearest to use: thrived, longer, staphylococcus, directed, its, demme, used, rhetoric,
# Nearest to from: friars, the, a, inexact, xylophone, trance, licensees, transsexualism,
# Nearest to years: female, life, household, four, male, householder, expectancy, migrant,
# Nearest to b: moravia, iterations, diagnosing, calculus, egon, scribner, universally, william,
# Nearest to however: wipes, devastation, accusative, nigerians, promised, lax, others, awe,
# Nearest to would: throws, criterion, deniability, saving, steered, meets, warner, unlawful,
# Nearest to hit: hitting, tap, got, balls, picked, monists, justifications, elmira,
# Nearest to mean: hanun, reconnection, vox, acronym, homeomorphisms, me, familes, solely,
# Nearest to bbc: email, truer, brigid, articles, broadcast, nights, listing, april,
# Nearest to channel: daniele, loglan, habermas, marysville, colossal, cve, bsi, deliver,
# Nearest to experience: cru, gras, think, maupin, tellurium, auc, respectful, cyberspace,
# Nearest to heavy: orchestral, dystopian, rectifiers, registered, statewide, percussive, white, supercar,
# Nearest to quite: royale, succinic, precluded, expecting, purists, asher, rstenberg, occupy,
# Nearest to centre: metro, wall, absalon, tallaght, steamship, square, attractions, annotate,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0453 0.0518 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0941 0.0507 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0884 0.0507 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0428 0.0503 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0708 0.0506 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0435 0.0514 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0533 0.0505 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0783 0.0510 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0923 0.0505 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0788 0.0506 sec/batch
# Nearest to during: weather, workout, helped, gunner, mongol, the, ahead, crimean,
# Nearest to four: one, three, two, five, six, zero, seven, years,
# Nearest to use: longer, used, its, thrived, staphylococcus, directed, almost, yours,
# Nearest to from: the, friars, a, berbers, galla, bulgars, inexact, stemmed,
# Nearest to years: female, life, four, household, six, zero, three, householder,
# Nearest to b: moravia, iterations, egon, diagnosing, calculus, scribner, william, aedh,
# Nearest to however: accusative, nigerians, wipes, devastation, had, dismembered, others, enlist,
# Nearest to would: throws, criterion, steered, deniability, meets, saving, understandably, warner,
# Nearest to hit: hitting, tap, got, monists, battleship, picked, balls, elmira,
# Nearest to mean: hanun, reconnection, acronym, vox, familes, expedited, coset, solely,
# Nearest to bbc: truer, email, brigid, nights, broadcast, listing, articles, april,
# Nearest to channel: daniele, loglan, habermas, affiliate, marysville, colossal, cve, deliver,
# Nearest to experience: gras, cru, maupin, newark, polices, auc, think, tellurium,
# Nearest to heavy: orchestral, dystopian, registered, rectifiers, statewide, percussive, throat, supercar,
# Nearest to quite: precluded, succinic, royale, purists, occupy, asher, unicameral, ztt,
# Nearest to centre: metro, absalon, wall, tallaght, steamship, triumphal, square, attractions,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0439 0.0519 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0181 0.0507 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0133 0.0505 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0502 0.0507 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0933 0.0508 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1376 0.0507 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1360 0.0504 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0424 0.0505 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0423 0.0504 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0549 0.0507 sec/batch
# Nearest to during: weather, helped, gunner, workout, mongol, amusements, avidly, ahead,
# Nearest to four: one, three, six, two, five, zero, seven, total,
# Nearest to use: longer, used, thrived, keystroke, its, staphylococcus, almost, directed,
# Nearest to from: friars, the, a, slave, galla, surrender, meticulously, encircle,
# Nearest to years: female, life, household, four, zero, householder, male, birth,
# Nearest to b: moravia, egon, iterations, diagnosing, scribner, aedh, william, universally,
# Nearest to however: devastation, accusative, nigerians, wipes, had, enlist, to, trustees,
# Nearest to would: criterion, deniability, throws, steered, understandably, problem, deterministic, hewson,
# Nearest to hit: hitting, tap, got, monists, elmira, justifications, battleship, picked,
# Nearest to mean: hanun, reconnection, vox, acronym, familes, coset, unending, expedited,
# Nearest to bbc: truer, brigid, email, listing, broadcast, nights, astrologically, hot,
# Nearest to channel: daniele, loglan, habermas, affiliate, bsi, colossal, marysville, rebranding,
# Nearest to experience: gras, cru, maupin, newark, cyberspace, think, tellurium, auc,
# Nearest to heavy: dystopian, orchestral, throat, registered, rectifiers, white, percussive, poses,
# Nearest to quite: royale, precluded, succinic, purists, rstenberg, unicameral, ztt, difficult,
# Nearest to centre: metro, wall, absalon, tallaght, triumphal, square, attractions, steamship,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9971 0.0517 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0371 0.0507 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0368 0.0506 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0425 0.0507 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0703 0.0507 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0692 0.0492 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0110 0.0506 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9786 0.0506 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0171 0.0513 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9838 0.0506 sec/batch
# Nearest to during: weather, helped, gunner, workout, amusements, ahead, avidly, refuel,
# Nearest to four: one, three, five, two, six, zero, seven, nine,
# Nearest to use: longer, used, thrived, rhetoric, staphylococcus, its, demme, hilde,
# Nearest to from: friars, the, a, inexact, meticulously, surrender, stemmed, galla,
# Nearest to years: female, life, household, householder, four, male, age, birth,
# Nearest to b: william, d, egon, moravia, statesman, ballerina, writer, ashikaga,
# Nearest to however: accusative, devastation, wipes, symbiotic, nigerians, had, awe, others,
# Nearest to would: criterion, throws, understandably, problem, deniability, steered, deterministic, meets,
# Nearest to hit: hitting, tap, got, battleship, elmira, henchman, picked, balls,
# Nearest to mean: hanun, reconnection, vox, coset, familes, me, acronym, homeomorphisms,
# Nearest to bbc: truer, brigid, listing, email, april, hot, nights, broadcast,
# Nearest to channel: daniele, loglan, affiliate, habermas, bsi, colossal, marysville, rebranding,
# Nearest to experience: gras, maupin, cru, newark, think, cyberspace, tellurium, polices,
# Nearest to heavy: dystopian, orchestral, rectifiers, registered, percussive, throat, constitutes, poses,
# Nearest to quite: royale, precluded, occupy, purists, dagobert, ztt, difficult, expecting,
# Nearest to centre: wall, metro, absalon, triumphal, tallaght, attractions, steamship, performing,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9919 0.0515 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9340 0.0508 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0149 0.0506 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0168 0.0506 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0251 0.0507 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9943 0.0507 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8970 0.0506 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9554 0.0506 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9205 0.0504 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9724 0.0505 sec/batch
# Nearest to during: helped, weather, gunner, avidly, ahead, amusements, workout, mongol,
# Nearest to four: one, two, five, three, six, zero, seven, years,
# Nearest to use: used, longer, staphylococcus, almost, its, thrived, rhetoric, hilde,
# Nearest to from: the, a, friars, an, galla, inexact, meticulously, registered,
# Nearest to years: female, life, household, four, householder, age, male, zero,
# Nearest to b: moravia, iterations, universally, diagnosing, rearranges, egon, aedh, astbury,
# Nearest to however: devastation, wipes, accusative, symbiotic, nigerians, to, others, widely,
# Nearest to would: criterion, problem, understandably, throws, deniability, steered, deterministic, meets,
# Nearest to hit: hitting, tap, balls, got, outs, inexpensively, ejecting, handlebar,
# Nearest to mean: hanun, reconnection, coset, vox, acronym, me, familes, homeomorphisms,
# Nearest to bbc: truer, email, brigid, listing, dvds, broadcast, hot, april,
# Nearest to channel: daniele, affiliate, loglan, habermas, marysville, upn, bsi, aired,
# Nearest to experience: gras, cyberspace, maupin, newark, cru, tellurium, auc, think,
# Nearest to heavy: dystopian, orchestral, rectifiers, percussive, plunged, constitutes, cyan, registered,
# Nearest to quite: royale, occupy, precluded, asher, ztt, expecting, purists, difficult,
# Nearest to centre: wall, metro, absalon, attractions, triumphal, tallaght, steamship, performing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9963 0.0515 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9808 0.0505 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9963 0.0504 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0235 0.0506 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0427 0.0507 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9780 0.0505 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9978 0.0507 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9866 0.0506 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0061 0.0505 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0000 0.0504 sec/batch
# Nearest to during: helped, weather, avidly, amusements, gunner, workout, ahead, squads,
# Nearest to four: one, five, three, two, six, zero, seven, nine,
# Nearest to use: used, longer, its, almost, staphylococcus, rhetoric, demme, thrived,
# Nearest to from: the, a, friars, an, meticulously, galla, inexact, stemmed,
# Nearest to years: female, four, life, household, six, deaths, age, zero,
# Nearest to b: moravia, ashikaga, d, aedh, ballerina, egon, william, writer,
# Nearest to however: devastation, nigerians, alleanza, widely, had, others, lax, accusative,
# Nearest to would: criterion, deniability, understandably, steered, throws, meets, hewson, froggy,
# Nearest to hit: hitting, tap, balls, inexpensively, ejecting, morris, elmira, skynyrd,
# Nearest to mean: hanun, reconnection, vox, coset, acronym, familes, me, toga,
# Nearest to bbc: truer, brigid, email, listing, broadcast, week, dvds, hot,
# Nearest to channel: daniele, loglan, habermas, affiliate, marysville, rebranding, colossal, upn,
# Nearest to experience: gras, cyberspace, maupin, cru, newark, tellurium, pcbs, think,
# Nearest to heavy: dystopian, rectifiers, plunged, orchestral, constitutes, percussive, cyan, registered,
# Nearest to quite: royale, ztt, purists, precluded, asher, occupy, expecting, variety,
# Nearest to centre: wall, metro, absalon, tallaght, modestly, seat, performing, triumphal,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0051 0.0516 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9669 0.0506 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9700 0.0505 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0042 0.0505 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0152 0.0508 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0059 0.0512 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0076 0.0507 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9624 0.0505 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9905 0.0502 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0140 0.0507 sec/batch
# Nearest to during: helped, weather, gunner, musab, the, avidly, amusements, refuel,
# Nearest to four: one, three, five, six, two, zero, nine, seven,
# Nearest to use: used, its, longer, almost, staphylococcus, mawr, demme, myst,
# Nearest to from: the, a, friars, berbers, galla, facilitated, slave, an,
# Nearest to years: female, life, four, six, zero, three, deaths, five,
# Nearest to b: moravia, ballerina, ashikaga, d, aedh, egon, astbury, diagnosing,
# Nearest to however: nigerians, devastation, had, lax, alleanza, speakers, others, substring,
# Nearest to would: criterion, understandably, problem, meets, hewson, froggy, steered, deterministic,
# Nearest to hit: hitting, tap, balls, ejecting, inexpensively, got, justifications, skynyrd,
# Nearest to mean: hanun, reconnection, coset, vox, acronym, me, hesitant, inserts,
# Nearest to bbc: truer, brigid, listing, week, broadcast, email, dvds, hot,
# Nearest to channel: daniele, loglan, affiliate, habermas, rebranding, marysville, upn, colossal,
# Nearest to experience: gras, cyberspace, maupin, newark, cru, pcbs, polices, weasel,
# Nearest to heavy: dystopian, constitutes, percussive, rectifiers, plunged, orchestral, registered, cyan,
# Nearest to quite: unicameral, ztt, royale, succinic, purists, occupy, precluded, difficult,
# Nearest to centre: wall, metro, tallaght, absalon, seat, modestly, triumphal, performing,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9816 0.0521 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0801 0.0508 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0409 0.0506 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0427 0.0504 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9605 0.0506 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9497 0.0503 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9788 0.0511 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9057 0.0508 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9807 0.0507 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9734 0.0507 sec/batch
# Nearest to during: weather, helped, avidly, gunner, amusements, workout, ahead, refuel,
# Nearest to four: one, three, five, six, two, zero, seven, nine,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8106 0.0505 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8629 0.0506 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8972 0.0506 sec/batch
# Nearest to during: before, avidly, at, after, weather, helped, period, arrival,
# Nearest to four: one, five, three, two, six, zero, seven, nine,
# Nearest to use: used, longer, which, almost, terminology, of, its, kannada,
# Nearest to from: the, a, by, of, which, in, first, and,
# Nearest to years: age, female, zero, six, five, four, over, three,
# Nearest to b: moravia, rearranges, ellensburg, aedh, ashikaga, astbury, ilya, writer,
# Nearest to however: had, widely, although, would, celsius, to, were, almost,
# Nearest to would: however, dixieland, able, predicted, deniability, criterion, stoppages, problem,
# Nearest to hit: hitting, ejecting, balls, hits, lampooned, morris, outs, tightening,
# Nearest to mean: hesitant, hanun, vox, acronym, truncation, toon, sun, unending,
# Nearest to bbc: listing, brigid, april, programme, august, hot, britain, palestine,
# Nearest to channel: upn, daniele, affiliate, tv, enjoy, broadcast, taper, loglan,
# Nearest to experience: cyberspace, newark, strawson, molluscs, tacit, gagnon, gras, necessary,
# Nearest to heavy: registered, dystopian, in, from, offshoots, halifax, breach, constitutes,
# Nearest to quite: ztt, directional, underpinning, royale, because, silesian, very, dagobert,
# Nearest to centre: wall, performing, gibbous, hough, intersection, birmingham, ossification, wtc,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8228 0.0517 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8528 0.0504 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8360 0.0511 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8395 0.0511 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8683 0.0502 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8713 0.0508 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8456 0.0507 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8314 0.0508 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8488 0.0507 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8856 0.0507 sec/batch
# Nearest to during: before, avidly, at, the, in, period, weather, after,
# Nearest to four: one, five, three, two, six, zero, seven, nine,
# Nearest to use: used, longer, almost, which, its, kannada, mawr, of,
# Nearest to from: the, a, by, of, which, in, and, first,
# Nearest to years: age, six, five, zero, female, four, three, over,
# Nearest to b: moravia, ellensburg, rearranges, astbury, aedh, ashikaga, anderssen, ilya,
# Nearest to however: had, widely, celsius, although, would, were, almost, symbiotic,
# Nearest to would: however, able, dixieland, hope, problem, predicted, criterion, extinguished,
# Nearest to hit: hitting, ejecting, balls, hits, morris, lampooned, outs, tightening,
# Nearest to mean: hesitant, hanun, vox, acronym, truncation, sun, unending, toon,
# Nearest to bbc: listing, brigid, april, august, programme, britain, hot, buckyballs,
# Nearest to channel: daniele, upn, affiliate, enjoy, tv, broadcast, taper, loglan,
# Nearest to experience: cyberspace, newark, strawson, molluscs, tacit, gras, perfected, visitor,
# Nearest to heavy: registered, dystopian, from, in, offshoots, ulaanbaatar, sandman, incorporated,
# Nearest to quite: ztt, underpinning, very, royale, because, variety, directional, silesian,
# Nearest to centre: hough, auld, birmingham, gibbous, wends, wall, battalions, wtc,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8583 0.0519 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8297 0.0505 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8213 0.0507 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8229 0.0506 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9266 0.0511 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8303 0.0509 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9681 0.0510 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9179 0.0507 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9262 0.0506 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8095 0.0506 sec/batch
# Nearest to during: at, before, the, period, after, avidly, weather, arrival,
# Nearest to four: one, five, three, two, six, zero, nine, seven,
# Nearest to use: used, longer, which, almost, terminology, mawr, kannada, accepted,
# Nearest to from: the, a, by, in, of, which, into, first,
# Nearest to years: zero, age, female, five, six, four, over, three,
# Nearest to b: moravia, anderssen, ellensburg, ilya, astbury, rearranges, ashikaga, d,
# Nearest to however: had, widely, were, celsius, although, would, to, almost,
# Nearest to would: however, dixieland, predicted, able, extinguished, deniability, hope, flirty,
# Nearest to hit: hitting, ejecting, balls, hits, struck, morris, save, tightening,
# Nearest to mean: hesitant, hanun, acronym, vox, truncation, sun, toon, solar,
# Nearest to bbc: listing, brigid, august, april, programme, britain, britons, palestine,
# Nearest to channel: daniele, upn, affiliate, enjoy, loglan, taper, habermas, omri,
# Nearest to experience: cyberspace, newark, strawson, molluscs, gras, tacit, maupin, gagnon,
# Nearest to heavy: in, from, registered, dystopian, offshoots, ulaanbaatar, sandman, incorporated,
# Nearest to quite: ztt, royale, very, underpinning, directional, silesian, because, difficult,
# Nearest to centre: wends, birmingham, hough, battalions, wall, gibbous, auld, wtc,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7972 0.0512 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8644 0.0504 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7868 0.0507 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8866 0.0505 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8622 0.0507 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8453 0.0508 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8835 0.0336 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8624 0.0505 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8206 0.0506 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8893 0.0506 sec/batch
# Nearest to during: at, the, avidly, after, before, weather, period, arrival,
# Nearest to four: one, five, three, two, six, zero, nine, seven,
# Nearest to use: used, longer, which, terminology, masoretes, almost, kannada, its,
# Nearest to from: the, a, of, in, by, which, into, and,
# Nearest to years: age, zero, five, female, four, over, six, three,
# Nearest to b: moravia, anderssen, d, eight, ilya, ellensburg, ashikaga, statesman,
# Nearest to however: had, celsius, widely, to, were, almost, although, would,
# Nearest to would: predicted, however, dixieland, able, problem, extinguished, considering, criterion,
# Nearest to hit: hitting, ejecting, balls, hits, lampooned, abba, save, foreshadowing,
# Nearest to mean: hesitant, hanun, vox, truncation, acronym, sun, solar, mozi,
# Nearest to bbc: listing, brigid, august, april, palestine, programme, buckyballs, hot,
# Nearest to channel: daniele, upn, affiliate, enjoy, taper, loglan, tv, habermas,
# Nearest to experience: cyberspace, newark, molluscs, strawson, gras, tacit, falls, visitor,
# Nearest to heavy: registered, dystopian, offshoots, from, sandman, in, incorporated, punk,
# Nearest to quite: ztt, directional, royale, variety, silesian, because, very, underpinning,
# Nearest to centre: wtc, wall, precincts, wends, chapterhouse, gibbous, hough, performing,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7950 0.0515 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8378 0.0505 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8169 0.0506 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8370 0.0505 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8535 0.0507 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8218 0.0505 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9006 0.0506 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7578 0.0506 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8416 0.0505 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8278 0.0505 sec/batch
# Nearest to during: at, before, after, period, avidly, the, arrival, weather,
# Nearest to four: one, five, three, two, six, zero, seven, nine,
# Nearest to use: used, longer, which, almost, such, of, many, terminology,
# Nearest to from: the, a, in, of, by, which, into, and,
# Nearest to years: age, zero, female, five, four, six, three, over,
# Nearest to b: moravia, ellensburg, rearranges, iterations, diagnosing, mitsumi, sepals, kilotons,
# Nearest to however: had, although, widely, to, were, celsius, would, symbiotic,
# Nearest to would: however, predicted, able, that, problem, dixieland, extinguished, deniability,
# Nearest to hit: hitting, ejecting, balls, hits, outs, lampooned, tightening, struck,
# Nearest to mean: hanun, hesitant, vox, truncation, acronym, sun, coset, solar,
# Nearest to bbc: listing, brigid, august, april, programme, palestine, buckyballs, relaunched,
# Nearest to channel: daniele, upn, affiliate, enjoy, taper, loglan, tv, broadcast,
# Nearest to experience: cyberspace, newark, strawson, molluscs, tacit, gras, demonstrate, view,
# Nearest to heavy: registered, in, from, offshoots, incorporated, dystopian, sandman, percussive,
# Nearest to quite: ztt, directional, variety, because, underpinning, royale, dagobert, optimizing,
# Nearest to centre: wtc, performing, precincts, gibbous, hough, chapterhouse, wall, detectors,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7760 0.0516 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8264 0.0505 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8483 0.0507 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7968 0.0505 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8129 0.0506 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8979 0.0506 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8224 0.0504 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8452 0.0505 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8651 0.0505 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8249 0.0508 sec/batch
# Nearest to during: at, before, avidly, the, period, after, weather, in,
# Nearest to four: one, five, three, two, six, zero, nine, seven,
# Nearest to use: used, longer, almost, which, of, its, in, accepted,
# Nearest to from: the, a, which, of, by, in, into, on,
# Nearest to years: age, female, five, zero, six, four, three, male,
# Nearest to b: moravia, ellensburg, ashikaga, rearranges, anderssen, astbury, sepals, kilotons,
# Nearest to however: had, celsius, were, although, would, almost, widely, secondary,
# Nearest to would: however, predicted, dixieland, able, extinguished, flirty, stoppages, deniability,
# Nearest to hit: hitting, ejecting, balls, hits, morris, tightening, lampooned, save,
# Nearest to mean: hesitant, hanun, acronym, truncation, vox, unending, catch, astra,
# Nearest to bbc: listing, brigid, programme, august, april, buckyballs, palestine, hot,
# Nearest to channel: daniele, upn, affiliate, enjoy, taper, loglan, tv, omri,
# Nearest to experience: cyberspace, newark, strawson, molluscs, gras, demonstrate, view, falls,
# Nearest to heavy: registered, in, offshoots, from, sandman, dystopian, percussive, incorporated,
# Nearest to quite: ztt, directional, underpinning, royale, very, because, variety, difficult,
# Nearest to centre: chapterhouse, performing, hough, wtc, detectors, gibbous, precincts, athenians,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8449 0.0517 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8725 0.0506 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8478 0.0508 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8047 0.0507 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8489 0.0505 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8310 0.0507 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8528 0.0506 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8536 0.0507 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8268 0.0508 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8248 0.0504 sec/batch
# Nearest to during: the, before, period, in, silla, at, avidly, weather,
# Nearest to four: one, three, five, six, two, zero, nine, seven,
# Nearest to use: used, longer, which, almost, of, its, accepted, normally,
# Nearest to from: the, a, of, which, by, in, into, and,
# Nearest to years: zero, five, six, four, age, female, three, over,
# Nearest to b: moravia, ellensburg, rearranges, diagnosing, ashikaga, sepals, anderssen, reynold,
# Nearest to however: had, would, although, celsius, to, these, were, almost,
# Nearest to would: however, able, dixieland, considering, that, extinguished, stoppages, them,
# Nearest to hit: hitting, ejecting, balls, hits, morris, tightening, foreshadowing, struck,
# Nearest to mean: hesitant, hanun, acronym, truncation, vox, sun, catch, unending,
# Nearest to bbc: listing, brigid, august, palestine, april, programme, buckyballs, hot,
# Nearest to channel: daniele, upn, affiliate, enjoy, taper, tv, loglan, habermas,
# Nearest to experience: cyberspace, strawson, newark, molluscs, taught, gras, demonstrate, view,
# Nearest to heavy: registered, sandman, from, offshoots, in, incorporated, percussive, orchestral,
# Nearest to quite: ztt, very, underpinning, royale, directional, because, difficult, least,
# Nearest to centre: detectors, hough, chapterhouse, precincts, performing, wends, auld, dunfermline,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8618 0.0518 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8075 0.0515 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9564 0.0513 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8681 0.0507 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8833 0.0507 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8075 0.0505 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7859 0.0505 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8484 0.0514 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7373 0.0509 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8455 0.0505 sec/batch
# Nearest to during: before, period, the, avidly, at, weather, until, after,
# Nearest to four: one, five, three, two, six, zero, nine, seven,
# Nearest to use: used, longer, almost, which, of, in, many, its,
# Nearest to from: the, a, in, of, which, into, by, on,
# Nearest to years: zero, female, age, five, four, over, six, birth,
# Nearest to b: moravia, writer, anderssen, d, eight, five, statesman, ashikaga,
# Nearest to however: had, although, to, would, were, celsius, almost, these,
# Nearest to would: however, dixieland, predicted, flirty, that, able, considering, extinguished,
# Nearest to hit: hitting, ejecting, balls, hits, lampooned, morris, tightening, struck,
# Nearest to mean: hesitant, hanun, vox, acronym, truncation, solar, is, catch,
# Nearest to bbc: listing, brigid, august, april, programme, britons, hot, palestine,
# Nearest to channel: daniele, upn, affiliate, enjoy, taper, habermas, loglan, tv,
# Nearest to experience: cyberspace, newark, strawson, molluscs, view, gras, taught, demonstrate,
# Nearest to heavy: in, registered, sandman, from, offshoots, percussive, by, incorporated,
# Nearest to quite: ztt, very, many, royale, underpinning, directional, demographics, dagobert,
# Nearest to centre: chapterhouse, precincts, detectors, wends, hough, gibbous, performing, athenians,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8492 0.0517 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8259 0.0504 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
